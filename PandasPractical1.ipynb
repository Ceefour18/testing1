# %%
import pandas as pd
path = "/content/sample_data/california_housing_test.csv"
pd.read_csv(path)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df=pd.read_csv(path)
print (pd)
# Out:
# <module 'pandas' from '/usr/local/lib/python3.10/dist-packages/pandas/__init__.py'>

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value       PiM
# 0      1537.0       606.0         6.6085            344700.0  0.001537
# 1       809.0       277.0         3.5990            176500.0  0.000809
# 2      1484.0       495.0         5.7934            270500.0  0.001484
# 3        49.0        11.0         6.1359            330000.0  0.000049
# 4       850.0       237.0         2.9375             81700.0  0.000850

# %%
df.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value       PiM
# 2995      1258.0       607.0         1.1790            225000.0  0.001258
# 2996      3496.0      1036.0         3.3906            237200.0  0.003496
# 2997       693.0       220.0         2.2895             62000.0  0.000693
# 2998        46.0        14.0         3.2708            162500.0  0.000046
# 2999       753.0       260.0         8.5608            500001.0  0.000753

# %%
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value       PiM
# 0      1537.0       606.0         6.6085            344700.0  0.001537
# ...

# %%
df.head(7)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0
# ...

# %%
df.tail(10)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2990    -118.23     34.09                49.0       1638.0           456.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2994    -117.93     33.86                35.0        931.0           181.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value       PiM
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
#  9   PiM                 3000 non-null   float64
# dtypes: float64(10)
# memory usage: 234.5 KB

# %%
df.describe()  ## this is discriptive Analysis of the dataset
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %% [markdown]
# **To discover duplicates, we can use the duplicated() method. The duplicated() method returns a Boolean values for each row:**

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Length: 3000, dtype: bool

# %% [markdown]
# Pandas at[] is used to return data in a dataframe at the passed location. The passed location is in the format [position, Column Name].

# %%
# creating position and label variables
position = 2
label = 'total_rooms'

# calling .at[] method
output = df.at[position, label]
print (output)
# Out:
# 3589.0

# %% [markdown]
# **LET'S TALK ABOUT PANDAS ATTRIBUTES**
#
#
# *   Attributes are the properties of a DataFrame that can be used to fetch data or any information related to a particular dataframe.

# %% [markdown]
# **1. COLUMN:** Its used to view the header in our dataset

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
# **2. AXES:** This attribute is used when we want to fetch the values of all row labels and all column labels at a time.

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=3000, step=1),
#  Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#         'total_bedrooms', 'population', 'households', 'median_income',
#         'median_house_value', 'PiM'],
#        dtype='object')]

# %% [markdown]
# **3. DTYPES:** This attribute is used to display the data type for each column of a particular dataframe.

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# PiM                   float64
# dtype: object

# %% [markdown]
# **4. SHAPE**: This attribute is used to display the total number of rows and columns of a particular data frame.

# %%
df.shape
# Out:
# (3000, 10)

# %% [markdown]
# **6. NDIM:** ndim means the number of dimensions and this attribute is used to display the number of dimensions of a particular data frame

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# **7. INDEX** This attribute is used to display the range of values in a data frame object.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3000, step=1)

# %% [markdown]
# **8. VALUES:** This attribute is used to represent the values/data of dataframe in NumPy array form.

# %% [markdown]
# You can add a new column with a derived data

# %%
df['PopulationInMillions'] = df['population']/1000000
print (df)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value  \
# ...

# %%
df.values
# Out:
# array([[-1.22050e+02,  3.73700e+01,  2.70000e+01, ...,  6.60850e+00,
#          3.44700e+05,  1.53700e-03],
#        [-1.18300e+02,  3.42600e+01,  4.30000e+01, ...,  3.59900e+00,
#          1.76500e+05,  8.09000e-04],
#        [-1.17810e+02,  3.37800e+01,  2.70000e+01, ...,  5.79340e+00,
#          2.70500e+05,  1.48400e-03],
#        ...,
#        [-1.19700e+02,  3.63000e+01,  1.00000e+01, ...,  2.28950e+00,
#          6.20000e+04,  6.93000e-04],
#        [-1.17120e+02,  3.41000e+01,  4.00000e+01, ...,  3.27080e+00,
#          1.62500e+05,  4.60000e-05],
#        [-1.19630e+02,  3.44200e+01,  4.20000e+01, ...,  8.56080e+00,
#          5.00001e+05,  7.53000e-04]])

# %% [markdown]
# **Let's save our dataset**

# %%
df.to_csv('california_housing_test.csv')

# %% [markdown]
# **Lets perform some computations on our dataframe**
#
# A. You can **rename** the columns in your dataset

# %%
df.rename(columns ={'PopulationInMillions': 'PiM'})
list(df)
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value',
#  'PiM']

# %% [markdown]
# B. You can compute the **MEAN** value of a numeric Column

# %%
population_mean = df.population.mean()
print ("Population Mean : ", population_mean)
# Out:
# Population Mean :  1402.7986666666666

# %% [markdown]
# C. You can calculate the **MEDIAN** value of a column

# %%
Population_median = df.population.median()
print ("Population median : ", Population_median)
# Out:
# Population median :  1155.0

# %% [markdown]
# **WEB SCRAPPING:** a technique used to extract the content of a table in a website invoves

# %%
james_bond_tables = pd.read_html( "https://en.wikipedia.org/wiki/List_of_James_Bond_novels_and_short_stories")
james_bond_data = james_bond_tables[1].convert_dtypes()

# %%
print (james_bond_data)
# Out:
#                                  Title             Author      Publisher  \
# 0                        Casino Royale        Ian Fleming  Jonathan Cape
# 1                     Live and Let Die        Ian Fleming  Jonathan Cape
# 2                            Moonraker        Ian Fleming  Jonathan Cape
# 3                 Diamonds Are Forever        Ian Fleming  Jonathan Cape
# 4               From Russia, with Love        Ian Fleming  Jonathan Cape
# 5                               Dr. No        Ian Fleming  Jonathan Cape
# 6                           Goldfinger        Ian Fleming  Jonathan Cape
# 7                   For Your Eyes Only        Ian Fleming  Jonathan Cape
# 8                          Thunderball  Ian Fleming[nb 1]  Jonathan Cape
# 9                 The Spy Who Loved Me        Ian Fleming  Jonathan Cape
# 10     On Her Majesty's Secret Service        Ian Fleming  Jonathan Cape
# 11                 You Only Live Twice        Ian Fleming  Jonathan Cape
# ...

# %% [markdown]
# **COMPUTING DATA CORRELATION USING PANDAS**
#
# The corr() method calculates the relationship between each column in your data set.
#
# The corr() method ignores "not numeric" columns.
#
# Correlation could be **PERFECT**, **GOOD** OR **BAD**

# %%
df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925017           -0.064203     0.049865
# latitude            -0.925017  1.000000           -0.025143    -0.039632
# housing_median_age  -0.064203 -0.025143            1.000000    -0.367850
# total_rooms          0.049865 -0.039632           -0.367850     1.000000
# total_bedrooms       0.070869 -0.068245           -0.323154     0.937749
# population           0.111572 -0.117318           -0.299888     0.838867
# households           0.051062 -0.068296           -0.305171     0.914116
# median_income       -0.018701 -0.072363           -0.144315     0.221249
# median_house_value  -0.050662 -0.138428            0.091409     0.160427
# PiM                  0.111572 -0.117318           -0.299888     0.838867
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.070869    0.111572    0.051062      -0.018701
# ...

# %% [markdown]
# **PLOTTING USING PANDAS**
#
# Pandas uses the **plot()** method to create diagrams.
#
# But we need **Pyplot** submodule in **Matplotlib library** to visualize the diagram on the screen

# %%
import matplotlib.pyplot as plt
df.plot(kind = 'scatter', x = 'total_rooms', y = 'total_bedrooms')

plt.show()

# %%
df.plot(kind = 'hist', x = 'total_rooms', y = 'total_bedrooms')

plt.show()

# %%
df.plot(kind = 'bar', x = 'longitude', y = 'latitude')
plt.show()

# %%
df[:10][['longitude', 'latitude']].plot(kind = 'bar', x = 'longitude', y = 'latitude')
plt.show()

# %% [markdown]
# Here are some of the chart types you can plot in Pandas, along with their syntax:
#
# **1. Line Chart**
#
# df.plot(kind = 'line', x = 'column1', y = 'column2')
# plt.show()
#
# **2. Scatter Plot**
#
# df.plot(kind = 'scatter', x = 'column1', y = 'column2')
# plt.show()
#
#
# **3. Bar Chart**
#
# df.plot(kind = 'bar', x = 'column1', y = 'column2')
# plt.show()
#
# **4. Histogram**
#
# df.plot(kind = 'hist', x = 'column1', y = 'column2')
# plt.show()
#
#
# **5. Box Plot**
#
# df.plot(kind = 'box')
# plt.show()
#
# **6. Area Plot**
# df.plot(kind = 'area')
# plt.show()
#
# **7. Pie Chart**
#
# df['column1'].plot(kind='pie')
# plt.show()

# %% [markdown]
# **GIVE ME A LIST OF DIFFERENT KINDS OF CHARTS THAT CAN BE PLOTTED UNDER PANDAS AND THEIR SYNTAX**

# %%
import matplotlib.pyplot as plt
df.plot(kind = 'scatter', x = 'total_rooms', y = 'total_bedrooms')

plt.show()
